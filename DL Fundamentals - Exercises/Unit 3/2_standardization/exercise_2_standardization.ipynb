# %% [markdown]
# # Unit 3, Exercise 2: Standardization

# %% [markdown]
# This exercise is an extension of Exercise 1. Here, the goal is to add code to standardize the features such that they have a mean of 0 and a standard deviation of 1 as discussed in Unit 3.7.
#
# Most of the code below is identical to Exercise 1. To avoid not spoil the solution for Exercise 1, the same code parts are missing.

# %% [markdown]
# ## 1) Installing Libraries

# %% [markdown]
# You likely already have all libraries installed and don't need to do anything here.

# %%
# !pip install numpy pandas matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
# !pip install watermark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting watermark
#   Downloading watermark-2.4.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: ipython>=6.0 in /usr/local/lib/python3.10/dist-packages (from watermark) (7.34.0)
# Collecting importlib-metadata>=1.4 (from watermark)
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting py3nvml>=0.2 (from watermark)
#   Downloading py3nvml-0.2.7-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from watermark) (67.7.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->watermark) (3.15.0)
# Collecting jedi>=0.16 (from ipython>=6.0->watermark)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (4.8.0)
# Collecting xmltodict (from py3nvml>=0.2->watermark)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0->watermark) (0.2.6)
# Installing collected packages: xmltodict, jedi, importlib-metadata, py3nvml, watermark
# Successfully installed importlib-metadata-6.7.0 jedi-0.18.2 py3nvml-0.2.7 watermark-2.4.2 xmltodict-0.13.0

# %%
# %load_ext watermark
# %watermark -v -p numpy,pandas,matplotlib,torch
# Out:
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.34.0
#
# numpy     : 1.22.4
# pandas    : 1.5.3
# matplotlib: 3.7.1
# torch     : 2.0.1+cu118

# %% [markdown]
# ## 2) Loading the Dataset

# %% [markdown]
# We are using the familiar `read_csv` function from pandas to load the dataset:

# %%
import pandas as pd

# %%
df = pd.read_csv("data_banknote_authentication.txt", header=None)
df.head()
# Out:
#          0       1       2        3  4
# 0  3.62160  8.6661 -2.8073 -0.44699  0
# 1  4.54590  8.1674 -2.4586 -1.46210  0
# 2  3.86600 -2.6383  1.9242  0.10645  0
# 3  3.45660  9.5228 -4.0112 -3.59440  0
# 4  0.32924 -4.4552  4.5718 -0.98880  0

# %%
X_features = df[[0, 1, 2, 3]].values
y_labels = df[4].values

# %% [markdown]
# Number of examples and features:

# %%
X_features.shape
# Out:
# (1372, 4)

# %% [markdown]
# It is usually a good idea to look at the label distribution:

# %%
import numpy as np

np.bincount(y_labels)
# Out:
# array([762, 610])

# %% [markdown]
# ## 3) Defining a DataLoader

# %% [markdown]
# The `DataLoader` code is the same code code we used in Unit 3.6:

# %%
from torch.utils.data import Dataset, DataLoader


class MyDataset(Dataset):
    def __init__(self, X, y):

        self.features = torch.tensor(X, dtype=torch.float32)
        self.labels = torch.tensor(y, dtype=torch.float32)

    def __getitem__(self, index):
        x = self.features[index]
        y = self.labels[index]
        return x, y

    def __len__(self):
        return self.labels.shape[0]

# %% [markdown]
# We will be using 80% of the data for training, 20% of the data for validation. In a real-project, we would also have a separate dataset for the final test set (in this case, we do not have an explicit test set).

# %%
train_size = int(X_features.shape[0]*0.80)
train_size
# Out:
# 1097

# %%
val_size = X_features.shape[0] - train_size
val_size
# Out:
# 275

# %% [markdown]
# Using `torch.utils.data.random_split`, we generate the training and validation sets along with the respective data loaders:

# %%
import torch

dataset = MyDataset(X_features, y_labels)

torch.manual_seed(1)
train_set, val_set = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(
    dataset=train_set,
    batch_size=10,
    shuffle=True,
)

val_loader = DataLoader(
    dataset=val_set,
    batch_size=10,
    shuffle=False,
)

# %% [markdown]
# ## 4) Standardization

# %% [markdown]
# There are multiple ways to implement the standardization procedure. For this exercise, we are going to implement a procedure that standardizes the features after we created the data loader.
#
# Since this dataset has 4 features, there should be 4 means and 4 standard deviations we compute from the training set. We can do this as follows:

# %%
train_mean = torch.zeros(X_features.shape[1])

for x, y in train_loader:
    train_mean += x.sum(dim=0)

train_mean /= len(train_set)

train_std = torch.zeros(X_features.shape[1])
for x, y in train_loader:
    train_std += ((x - train_mean)**2).sum(dim=0)

train_std = torch.sqrt(train_std / (len(train_set)-1))

# %%
print("Feature means:", train_mean)
print("Feature std. devs:", train_std)
# Out:
# Feature means: tensor([ 0.3854,  1.8680,  1.4923, -1.1999])
# Feature std. devs: tensor([2.8575, 5.9216, 4.3869, 2.1041])

# %% [markdown]
# We compute the means and standard deviations by iterating over the training loader. This is an approach that even works for large datasets where the entire dataset doesn't fit into memory.
#
# A simpler approach, which only works for smaller datasets that fit into memory, is as follows:

# %%
all_x = []
for x, y in train_loader:
    all_x.append(x)

train_std = torch.concat(all_x).std(dim=0)
train_mean = torch.concat(all_x).mean(dim=0)

# %%
print("Feature means:", train_mean)
print("Feature std. devs:", train_std)
# Out:
# Feature means: tensor([ 0.3854,  1.8680,  1.4923, -1.1999])
# Feature std. devs: tensor([2.8575, 5.9216, 4.3869, 2.1041])

# %% [markdown]
# <font color='red'>YOUR TASK is now to implement a standardization function based on these training set parameters above:</font>

# %%
def standardize(df, train_mean, train_std):
    return (df - train_mean) / train_std

# %% [markdown]
# ## 5) Implementing the model

# %% [markdown]
# Here, we are resusing the same model code we used in Unit 3.6:

# %%
import torch

class LogisticRegression(torch.nn.Module):

    def __init__(self, num_features):
        super().__init__()
        self.linear = torch.nn.Linear(num_features, 1)

    def forward(self, x):
        logits = self.linear(x)
        probas = torch.sigmoid(logits)
        return probas

# %% [markdown]
# ## 6) The training loop

# %% [markdown]
# In this section, we are using the training loop from Unit 3.6. It's the exact same code except for some small modification: We added the line `if not batch_idx % 20` to only print the lost for every 20th batch (to reduce the number of output lines).
#
# <font color='red'>YOUR TASK is to use the standardization code correctly in the for loop. Then, find a good learning rate and epoch number to that you achieve a training and validation performance of at least 98%.</font>

# %%
import torch.nn.functional as F


torch.manual_seed(1)
model = LogisticRegression(num_features=4)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1) ## possible SOLUTION

num_epochs = 100 ## possible SOLUTION

for epoch in range(num_epochs):

    model = model.train()
    for batch_idx, (features, class_labels) in enumerate(train_loader):

        features = standardize(features, train_mean, train_std) ## SOLUTION
        probas = model(features)

        loss = F.binary_cross_entropy(probas, class_labels.view(probas.shape))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        ### LOGGING
        if not batch_idx % 20: # log every 20th batch
            print(f'Epoch: {epoch+1:03d}/{num_epochs:03d}'
                   f' | Batch {batch_idx:03d}/{len(train_loader):03d}'
                   f' | Loss: {loss:.2f}')
# Out:
# Epoch: 001/100 | Batch 000/110 | Loss: 0.93
# Epoch: 001/100 | Batch 020/110 | Loss: 0.48
# Epoch: 001/100 | Batch 040/110 | Loss: 0.52
# Epoch: 001/100 | Batch 060/110 | Loss: 0.28
# Epoch: 001/100 | Batch 080/110 | Loss: 0.22
# Epoch: 001/100 | Batch 100/110 | Loss: 0.23
# Epoch: 002/100 | Batch 000/110 | Loss: 0.31
# Epoch: 002/100 | Batch 020/110 | Loss: 0.20
# Epoch: 002/100 | Batch 040/110 | Loss: 0.34
# Epoch: 002/100 | Batch 060/110 | Loss: 0.21
# Epoch: 002/100 | Batch 080/110 | Loss: 0.22
# Epoch: 002/100 | Batch 100/110 | Loss: 0.20
# Epoch: 003/100 | Batch 000/110 | Loss: 0.13
# Epoch: 003/100 | Batch 020/110 | Loss: 0.22
# Epoch: 003/100 | Batch 040/110 | Loss: 0.19
# Epoch: 003/100 | Batch 060/110 | Loss: 0.29
# Epoch: 003/100 | Batch 080/110 | Loss: 0.17
# Epoch: 003/100 | Batch 100/110 | Loss: 0.13
# Epoch: 004/100 | Batch 000/110 | Loss: 0.08
# Epoch: 004/100 | Batch 020/110 | Loss: 0.08
# Epoch: 004/100 | Batch 040/110 | Loss: 0.22
# Epoch: 004/100 | Batch 060/110 | Loss: 0.24
# Epoch: 004/100 | Batch 080/110 | Loss: 0.06
# Epoch: 004/100 | Batch 100/110 | Loss: 0.16
# Epoch: 005/100 | Batch 000/110 | Loss: 0.26
# Epoch: 005/100 | Batch 020/110 | Loss: 0.11
# Epoch: 005/100 | Batch 040/110 | Loss: 0.06
# Epoch: 005/100 | Batch 060/110 | Loss: 0.13
# Epoch: 005/100 | Batch 080/110 | Loss: 0.13
# Epoch: 005/100 | Batch 100/110 | Loss: 0.12
# Epoch: 006/100 | Batch 000/110 | Loss: 0.10
# Epoch: 006/100 | Batch 020/110 | Loss: 0.08
# Epoch: 006/100 | Batch 040/110 | Loss: 0.23
# Epoch: 006/100 | Batch 060/110 | Loss: 0.07
# Epoch: 006/100 | Batch 080/110 | Loss: 0.06
# Epoch: 006/100 | Batch 100/110 | Loss: 0.17
# Epoch: 007/100 | Batch 000/110 | Loss: 0.07
# Epoch: 007/100 | Batch 020/110 | Loss: 0.03
# Epoch: 007/100 | Batch 040/110 | Loss: 0.09
# Epoch: 007/100 | Batch 060/110 | Loss: 0.03
# Epoch: 007/100 | Batch 080/110 | Loss: 0.15
# Epoch: 007/100 | Batch 100/110 | Loss: 0.12
# Epoch: 008/100 | Batch 000/110 | Loss: 0.13
# Epoch: 008/100 | Batch 020/110 | Loss: 0.09
# Epoch: 008/100 | Batch 040/110 | Loss: 0.07
# Epoch: 008/100 | Batch 060/110 | Loss: 0.08
# Epoch: 008/100 | Batch 080/110 | Loss: 0.06
# Epoch: 008/100 | Batch 100/110 | Loss: 0.10
# Epoch: 009/100 | Batch 000/110 | Loss: 0.16
# Epoch: 009/100 | Batch 020/110 | Loss: 0.15
# Epoch: 009/100 | Batch 040/110 | Loss: 0.02
# Epoch: 009/100 | Batch 060/110 | Loss: 0.06
# Epoch: 009/100 | Batch 080/110 | Loss: 0.06
# Epoch: 009/100 | Batch 100/110 | Loss: 0.16
# Epoch: 010/100 | Batch 000/110 | Loss: 0.08
# Epoch: 010/100 | Batch 020/110 | Loss: 0.05
# Epoch: 010/100 | Batch 040/110 | Loss: 0.05
# Epoch: 010/100 | Batch 060/110 | Loss: 0.05
# Epoch: 010/100 | Batch 080/110 | Loss: 0.07
# Epoch: 010/100 | Batch 100/110 | Loss: 0.01
# Epoch: 011/100 | Batch 000/110 | Loss: 0.05
# Epoch: 011/100 | Batch 020/110 | Loss: 0.04
# Epoch: 011/100 | Batch 040/110 | Loss: 0.21
# Epoch: 011/100 | Batch 060/110 | Loss: 0.05
# Epoch: 011/100 | Batch 080/110 | Loss: 0.09
# Epoch: 011/100 | Batch 100/110 | Loss: 0.04
# Epoch: 012/100 | Batch 000/110 | Loss: 0.14
# Epoch: 012/100 | Batch 020/110 | Loss: 0.04
# Epoch: 012/100 | Batch 040/110 | Loss: 0.06
# Epoch: 012/100 | Batch 060/110 | Loss: 0.04
# Epoch: 012/100 | Batch 080/110 | Loss: 0.08
# Epoch: 012/100 | Batch 100/110 | Loss: 0.03
# Epoch: 013/100 | Batch 000/110 | Loss: 0.06
# Epoch: 013/100 | Batch 020/110 | Loss: 0.03
# Epoch: 013/100 | Batch 040/110 | Loss: 0.08
# Epoch: 013/100 | Batch 060/110 | Loss: 0.11
# Epoch: 013/100 | Batch 080/110 | Loss: 0.13
# Epoch: 013/100 | Batch 100/110 | Loss: 0.27
# Epoch: 014/100 | Batch 000/110 | Loss: 0.06
# Epoch: 014/100 | Batch 020/110 | Loss: 0.05
# Epoch: 014/100 | Batch 040/110 | Loss: 0.02
# Epoch: 014/100 | Batch 060/110 | Loss: 0.08
# Epoch: 014/100 | Batch 080/110 | Loss: 0.04
# Epoch: 014/100 | Batch 100/110 | Loss: 0.05
# Epoch: 015/100 | Batch 000/110 | Loss: 0.14
# Epoch: 015/100 | Batch 020/110 | Loss: 0.02
# Epoch: 015/100 | Batch 040/110 | Loss: 0.02
# Epoch: 015/100 | Batch 060/110 | Loss: 0.01
# Epoch: 015/100 | Batch 080/110 | Loss: 0.03
# Epoch: 015/100 | Batch 100/110 | Loss: 0.21
# Epoch: 016/100 | Batch 000/110 | Loss: 0.02
# Epoch: 016/100 | Batch 020/110 | Loss: 0.02
# Epoch: 016/100 | Batch 040/110 | Loss: 0.04
# Epoch: 016/100 | Batch 060/110 | Loss: 0.08
# Epoch: 016/100 | Batch 080/110 | Loss: 0.01
# Epoch: 016/100 | Batch 100/110 | Loss: 0.07
# Epoch: 017/100 | Batch 000/110 | Loss: 0.01
# Epoch: 017/100 | Batch 020/110 | Loss: 0.12
# Epoch: 017/100 | Batch 040/110 | Loss: 0.02
# Epoch: 017/100 | Batch 060/110 | Loss: 0.05
# Epoch: 017/100 | Batch 080/110 | Loss: 0.05
# Epoch: 017/100 | Batch 100/110 | Loss: 0.08
# Epoch: 018/100 | Batch 000/110 | Loss: 0.05
# Epoch: 018/100 | Batch 020/110 | Loss: 0.03
# Epoch: 018/100 | Batch 040/110 | Loss: 0.03
# Epoch: 018/100 | Batch 060/110 | Loss: 0.06
# Epoch: 018/100 | Batch 080/110 | Loss: 0.04
# Epoch: 018/100 | Batch 100/110 | Loss: 0.01
# Epoch: 019/100 | Batch 000/110 | Loss: 0.03
# Epoch: 019/100 | Batch 020/110 | Loss: 0.08
# Epoch: 019/100 | Batch 040/110 | Loss: 0.02
# Epoch: 019/100 | Batch 060/110 | Loss: 0.06
# Epoch: 019/100 | Batch 080/110 | Loss: 0.02
# Epoch: 019/100 | Batch 100/110 | Loss: 0.14
# Epoch: 020/100 | Batch 000/110 | Loss: 0.05
# Epoch: 020/100 | Batch 020/110 | Loss: 0.05
# Epoch: 020/100 | Batch 040/110 | Loss: 0.04
# Epoch: 020/100 | Batch 060/110 | Loss: 0.03
# Epoch: 020/100 | Batch 080/110 | Loss: 0.02
# Epoch: 020/100 | Batch 100/110 | Loss: 0.05
# Epoch: 021/100 | Batch 000/110 | Loss: 0.10
# Epoch: 021/100 | Batch 020/110 | Loss: 0.02
# Epoch: 021/100 | Batch 040/110 | Loss: 0.15
# Epoch: 021/100 | Batch 060/110 | Loss: 0.04
# Epoch: 021/100 | Batch 080/110 | Loss: 0.02
# Epoch: 021/100 | Batch 100/110 | Loss: 0.08
# Epoch: 022/100 | Batch 000/110 | Loss: 0.03
# Epoch: 022/100 | Batch 020/110 | Loss: 0.14
# Epoch: 022/100 | Batch 040/110 | Loss: 0.01
# Epoch: 022/100 | Batch 060/110 | Loss: 0.03
# Epoch: 022/100 | Batch 080/110 | Loss: 0.10
# Epoch: 022/100 | Batch 100/110 | Loss: 0.04
# Epoch: 023/100 | Batch 000/110 | Loss: 0.02
# Epoch: 023/100 | Batch 020/110 | Loss: 0.10
# Epoch: 023/100 | Batch 040/110 | Loss: 0.02
# Epoch: 023/100 | Batch 060/110 | Loss: 0.03
# Epoch: 023/100 | Batch 080/110 | Loss: 0.03
# Epoch: 023/100 | Batch 100/110 | Loss: 0.04
# Epoch: 024/100 | Batch 000/110 | Loss: 0.05
# Epoch: 024/100 | Batch 020/110 | Loss: 0.15
# Epoch: 024/100 | Batch 040/110 | Loss: 0.02
# Epoch: 024/100 | Batch 060/110 | Loss: 0.03
# Epoch: 024/100 | Batch 080/110 | Loss: 0.07
# Epoch: 024/100 | Batch 100/110 | Loss: 0.04
# Epoch: 025/100 | Batch 000/110 | Loss: 0.02
# Epoch: 025/100 | Batch 020/110 | Loss: 0.01
# Epoch: 025/100 | Batch 040/110 | Loss: 0.04
# Epoch: 025/100 | Batch 060/110 | Loss: 0.05
# Epoch: 025/100 | Batch 080/110 | Loss: 0.01
# Epoch: 025/100 | Batch 100/110 | Loss: 0.03
# Epoch: 026/100 | Batch 000/110 | Loss: 0.11
# Epoch: 026/100 | Batch 020/110 | Loss: 0.04
# Epoch: 026/100 | Batch 040/110 | Loss: 0.07
# Epoch: 026/100 | Batch 060/110 | Loss: 0.06
# Epoch: 026/100 | Batch 080/110 | Loss: 0.06
# Epoch: 026/100 | Batch 100/110 | Loss: 0.04
# Epoch: 027/100 | Batch 000/110 | Loss: 0.02
# Epoch: 078/100 | Batch 060/110 | Loss: 0.17
# Epoch: 078/100 | Batch 080/110 | Loss: 0.14
# Epoch: 078/100 | Batch 100/110 | Loss: 0.00
# Epoch: 079/100 | Batch 000/110 | Loss: 0.00
# Epoch: 079/100 | Batch 020/110 | Loss: 0.15
# Epoch: 079/100 | Batch 040/110 | Loss: 0.00
# Epoch: 079/100 | Batch 060/110 | Loss: 0.00
# Epoch: 079/100 | Batch 080/110 | Loss: 0.12
# Epoch: 079/100 | Batch 100/110 | Loss: 0.00
# Epoch: 080/100 | Batch 000/110 | Loss: 0.01
# Epoch: 080/100 | Batch 020/110 | Loss: 0.04
# Epoch: 080/100 | Batch 040/110 | Loss: 0.01
# Epoch: 080/100 | Batch 060/110 | Loss: 0.08
# Epoch: 080/100 | Batch 080/110 | Loss: 0.03
# Epoch: 080/100 | Batch 100/110 | Loss: 0.01
# Epoch: 081/100 | Batch 000/110 | Loss: 0.00
# Epoch: 081/100 | Batch 020/110 | Loss: 0.06
# Epoch: 081/100 | Batch 040/110 | Loss: 0.12
# Epoch: 081/100 | Batch 060/110 | Loss: 0.01
# Epoch: 081/100 | Batch 080/110 | Loss: 0.03
# Epoch: 081/100 | Batch 100/110 | Loss: 0.01
# Epoch: 082/100 | Batch 000/110 | Loss: 0.03
# Epoch: 082/100 | Batch 020/110 | Loss: 0.01
# Epoch: 082/100 | Batch 040/110 | Loss: 0.02
# Epoch: 082/100 | Batch 060/110 | Loss: 0.00
# Epoch: 082/100 | Batch 080/110 | Loss: 0.12
# Epoch: 082/100 | Batch 100/110 | Loss: 0.05
# Epoch: 083/100 | Batch 000/110 | Loss: 0.00
# Epoch: 083/100 | Batch 020/110 | Loss: 0.04
# Epoch: 083/100 | Batch 040/110 | Loss: 0.00
# Epoch: 083/100 | Batch 060/110 | Loss: 0.03
# Epoch: 083/100 | Batch 080/110 | Loss: 0.07
# Epoch: 083/100 | Batch 100/110 | Loss: 0.01
# Epoch: 084/100 | Batch 000/110 | Loss: 0.13
# Epoch: 084/100 | Batch 020/110 | Loss: 0.00
# Epoch: 084/100 | Batch 040/110 | Loss: 0.01
# Epoch: 084/100 | Batch 060/110 | Loss: 0.10
# Epoch: 084/100 | Batch 080/110 | Loss: 0.02
# Epoch: 084/100 | Batch 100/110 | Loss: 0.13
# Epoch: 085/100 | Batch 000/110 | Loss: 0.00
# Epoch: 085/100 | Batch 020/110 | Loss: 0.01
# Epoch: 085/100 | Batch 040/110 | Loss: 0.00
# Epoch: 085/100 | Batch 060/110 | Loss: 0.00
# Epoch: 085/100 | Batch 080/110 | Loss: 0.10
# Epoch: 085/100 | Batch 100/110 | Loss: 0.01
# Epoch: 086/100 | Batch 000/110 | Loss: 0.02
# Epoch: 086/100 | Batch 020/110 | Loss: 0.10
# Epoch: 086/100 | Batch 040/110 | Loss: 0.00
# Epoch: 086/100 | Batch 060/110 | Loss: 0.02
# Epoch: 086/100 | Batch 080/110 | Loss: 0.00
# Epoch: 086/100 | Batch 100/110 | Loss: 0.04
# Epoch: 095/100 | Batch 060/110 | Loss: 0.02
# Epoch: 095/100 | Batch 080/110 | Loss: 0.13
# Epoch: 095/100 | Batch 100/110 | Loss: 0.02
# Epoch: 096/100 | Batch 000/110 | Loss: 0.03
# Epoch: 096/100 | Batch 020/110 | Loss: 0.02
# Epoch: 096/100 | Batch 040/110 | Loss: 0.00
# Epoch: 096/100 | Batch 060/110 | Loss: 0.03
# Epoch: 096/100 | Batch 080/110 | Loss: 0.05
# Epoch: 096/100 | Batch 100/110 | Loss: 0.00
# Epoch: 097/100 | Batch 000/110 | Loss: 0.03
# Epoch: 097/100 | Batch 020/110 | Loss: 0.11
# Epoch: 097/100 | Batch 040/110 | Loss: 0.01
# Epoch: 097/100 | Batch 060/110 | Loss: 0.00
# Epoch: 097/100 | Batch 080/110 | Loss: 0.09
# Epoch: 097/100 | Batch 100/110 | Loss: 0.00
# Epoch: 098/100 | Batch 000/110 | Loss: 0.01
# Epoch: 098/100 | Batch 020/110 | Loss: 0.07
# Epoch: 098/100 | Batch 040/110 | Loss: 0.01
# Epoch: 098/100 | Batch 060/110 | Loss: 0.04
# Epoch: 098/100 | Batch 080/110 | Loss: 0.00
# Epoch: 098/100 | Batch 100/110 | Loss: 0.01
# Epoch: 099/100 | Batch 000/110 | Loss: 0.00
# Epoch: 099/100 | Batch 020/110 | Loss: 0.06
# Epoch: 099/100 | Batch 040/110 | Loss: 0.21
# Epoch: 099/100 | Batch 060/110 | Loss: 0.03
# Epoch: 099/100 | Batch 080/110 | Loss: 0.02
# Epoch: 099/100 | Batch 100/110 | Loss: 0.15
# Epoch: 100/100 | Batch 000/110 | Loss: 0.09
# Epoch: 100/100 | Batch 020/110 | Loss: 0.01
# Epoch: 100/100 | Batch 040/110 | Loss: 0.00
# Epoch: 100/100 | Batch 060/110 | Loss: 0.27
# Epoch: 100/100 | Batch 080/110 | Loss: 0.01
# Epoch: 100/100 | Batch 100/110 | Loss: 0.09

# %% [markdown]
# ## 7) Evaluating the results

# %% [markdown]
# Again, reusing the code from Unit 3.6, we will calculate the training and validation set accuracy.
#
# <font color='red'>Use the code below as is. What do you observe? And why?</font>

# %%
def compute_accuracy(model, dataloader):

    model = model.eval()

    correct = 0.0
    total_examples = 0

    for idx, (features, class_labels) in enumerate(dataloader):

        with torch.no_grad():
            features = standardize(features, train_mean, train_std)
            probas = model(features)

        pred = torch.where(probas > 0.5, 1, 0)
        lab = class_labels.view(pred.shape).to(pred.dtype)

        compare = lab == pred
        correct += torch.sum(compare)
        total_examples += len(compare)

    return correct / total_examples

# %%
train_acc = compute_accuracy(model, train_loader)
print(f"Accuracy: {train_acc*100:.2f}%")
# Out:
# Accuracy: 98.36%

# %% [markdown]
# <font color='red'>Notice that the code validation accuracy is not shown? It's part of the exercise to implement it :)</font>

# %%
## SOLUTION

val_acc = compute_accuracy(model, val_loader)
print(f"Accuracy: {val_acc*100:.2f}%")
# Out:
# Accuracy: 98.91%

# %% [markdown]
# <font color='red'>Now, add the standardization to the `compute_accuracy` function above and recompute the training and validation accuracy. What do you observe?</font>
