# %%
import torch

f = torch.tensor([[-1., -3., 4.], [-3., 3., -1.]])
target = torch.tensor([0, 1])
criterion = torch.nn.CrossEntropyLoss()
criterion(f, target)
# Out:
# tensor(2.5141)

# %%
from torch import nn
model = nn.LogSoftmax(dim = 1)
criterion = nn.NLLLoss()
criterion(model(f), target)
# Out:
# tensor(2.5141)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size = 5)
        self.conv2 = nn.Conv2d(32, 64, kernel_size = 5)
        self.fc1 = nn.Linear(256, 200)
        self.fc2 = nn.Linear(200, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), kernel_size = 3))
        x = F.relu(F.max_pool2d(self.conv2(x), kernel_size = 2))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
import torchvision

device = 'cuda'
train_set = torchvision.datasets.MNIST(root = 'train/', train = True, download = True)
train_input = train_set.data.view(-1, 1, 28, 28).float()
train_targets = train_set.targets

test_set = torchvision.datasets.MNIST(root = 'test/', train = False, download = True)
test_input = test_set.data.view(-1, 1, 28, 28).float()
test_targets = test_set.targets

lr, nb_epochs, batch_size, lambda_l2, lambda_l1 = 2e-1, 50, 100, 0., 0.00001

model = Net()

criterion = nn.CrossEntropyLoss()

model.to(device)
criterion.to(device)
train_input, train_targets = train_input.to(device), train_targets.to(device)
test_input, test_targets = test_input.to(device), test_targets.to(device)

mu, std = train_input.mean(), train_input.std()
train_input.sub_(mu).div_(std)
test_input.sub_(mu).div_(std)

for e in range(nb_epochs):
    if e % 5 == 0:
        lr /= 2
    optimizer = torch.optim.SGD(model.parameters(), lr = lr)

    for input, targets in zip(train_input.split(batch_size), train_targets.split(batch_size)):
        output = model(input)
        loss = criterion(output, targets)

        # L2 regularization
        for p in model.parameters():
            loss += lambda_l2 * p.pow(2).sum()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


        # L1 regularization
        # with torch.no_grad():
        #     for p in model.parameters():
        #         p.sub_(p.sign() * p.abs().clamp(max = lambda_l1))

    
    with torch.no_grad():
        train_output = model(train_input)
        train_loss = criterion(train_output, train_targets)
        # print(f"Train input: {train_input.size()}, Test input: {test_input.size()}")
        test_output = model(test_input)
        test_preds = torch.argmax(test_output, dim=1)

        test_loss = criterion(test_output, test_targets)
        test_errors = torch.count_nonzero(test_preds - test_targets)
        test_accuracy = 1 - float(test_errors) / test_targets.size(0)

        non_zero_p = 0
        for p in model.parameters():
            non_zero_p += p.count_nonzero()

        print(f"Epoch {e}:, training loss = {train_loss}, validation_loss = {test_loss}, validation_accuracy = {test_accuracy:2F}, non_zero_p = {non_zero_p}")
# Out:
# Epoch 0:, training loss = 0.0802069678902626, validation_loss = 0.07143258303403854, validation_accuracy = 0.976700, non_zero_p = 105506
# Epoch 1:, training loss = 0.046900298446416855, validation_loss = 0.04377318546175957, validation_accuracy = 0.985700, non_zero_p = 105506
# Epoch 2:, training loss = 0.03512101620435715, validation_loss = 0.03788353130221367, validation_accuracy = 0.987700, non_zero_p = 105506
# Epoch 3:, training loss = 0.02483223006129265, validation_loss = 0.031930096447467804, validation_accuracy = 0.989200, non_zero_p = 105506
# Epoch 4:, training loss = 0.019239705055952072, validation_loss = 0.029932910576462746, validation_accuracy = 0.990200, non_zero_p = 105506
# Epoch 5:, training loss = 0.014487617649137974, validation_loss = 0.02779056318104267, validation_accuracy = 0.990800, non_zero_p = 105506
# Epoch 6:, training loss = 0.012567013502120972, validation_loss = 0.027384541928768158, validation_accuracy = 0.991100, non_zero_p = 105506
# Epoch 7:, training loss = 0.011187659576535225, validation_loss = 0.02729659713804722, validation_accuracy = 0.991500, non_zero_p = 105506
# Epoch 8:, training loss = 0.009962844662368298, validation_loss = 0.0273650661110878, validation_accuracy = 0.991200, non_zero_p = 105506
# Epoch 9:, training loss = 0.008834066800773144, validation_loss = 0.02726457267999649, validation_accuracy = 0.991100, non_zero_p = 105506
# Epoch 10:, training loss = 0.006656576879322529, validation_loss = 0.024437880143523216, validation_accuracy = 0.991800, non_zero_p = 105506
# Epoch 11:, training loss = 0.006177022587507963, validation_loss = 0.024454805999994278, validation_accuracy = 0.991900, non_zero_p = 105506
# Epoch 12:, training loss = 0.005763480439782143, validation_loss = 0.024545835331082344, validation_accuracy = 0.991800, non_zero_p = 105506
# Epoch 13:, training loss = 0.005395319312810898, validation_loss = 0.0246067326515913, validation_accuracy = 0.992000, non_zero_p = 105506
# Epoch 14:, training loss = 0.004950485657900572, validation_loss = 0.024566655978560448, validation_accuracy = 0.992000, non_zero_p = 105506
# Epoch 15:, training loss = 0.004265326075255871, validation_loss = 0.02335239388048649, validation_accuracy = 0.992000, non_zero_p = 105506
# Epoch 16:, training loss = 0.004072082694619894, validation_loss = 0.02339189313352108, validation_accuracy = 0.991900, non_zero_p = 105506
# Epoch 17:, training loss = 0.003910827916115522, validation_loss = 0.02350403182208538, validation_accuracy = 0.992000, non_zero_p = 105506
# Epoch 18:, training loss = 0.003738658968359232, validation_loss = 0.023550624027848244, validation_accuracy = 0.991900, non_zero_p = 105506
# Epoch 19:, training loss = 0.003634392051026225, validation_loss = 0.023685770109295845, validation_accuracy = 0.991800, non_zero_p = 105506
# Epoch 20:, training loss = 0.003319037612527609, validation_loss = 0.02313253842294216, validation_accuracy = 0.992100, non_zero_p = 105506
# Epoch 21:, training loss = 0.0032513157930225134, validation_loss = 0.023181656375527382, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 22:, training loss = 0.003187886904925108, validation_loss = 0.023242443799972534, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 23:, training loss = 0.003128839423879981, validation_loss = 0.023277506232261658, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 24:, training loss = 0.003071310231462121, validation_loss = 0.023336458951234818, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 25:, training loss = 0.002972026588395238, validation_loss = 0.023212525993585587, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 26:, training loss = 0.002941254759207368, validation_loss = 0.023230718448758125, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 27:, training loss = 0.002913707634434104, validation_loss = 0.02325393445789814, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 28:, training loss = 0.0028867481742054224, validation_loss = 0.023276925086975098, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 29:, training loss = 0.002860510256141424, validation_loss = 0.023301390931010246, validation_accuracy = 0.992200, non_zero_p = 105506
# Epoch 30:, training loss = 0.0028333603404462337, validation_loss = 0.02330179698765278, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 31:, training loss = 0.0028185946866869926, validation_loss = 0.023309295997023582, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 32:, training loss = 0.0028054106514900923, validation_loss = 0.023318996652960777, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 33:, training loss = 0.002792554209008813, validation_loss = 0.02333034574985504, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 34:, training loss = 0.0027801035903394222, validation_loss = 0.023340437561273575, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 35:, training loss = 0.0027714057359844446, validation_loss = 0.02335154451429844, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 36:, training loss = 0.002764454809948802, validation_loss = 0.023358464241027832, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 37:, training loss = 0.002757762325927615, validation_loss = 0.023362375795841217, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 38:, training loss = 0.002751504071056843, validation_loss = 0.023367201909422874, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 39:, training loss = 0.0027455640956759453, validation_loss = 0.023374274373054504, validation_accuracy = 0.992400, non_zero_p = 105506
# Epoch 40:, training loss = 0.0027420618571341038, validation_loss = 0.023378927260637283, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 41:, training loss = 0.00273876148276031, validation_loss = 0.02338448353111744, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 42:, training loss = 0.0027355316560715437, validation_loss = 0.023384641855955124, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 43:, training loss = 0.0027324564289301634, validation_loss = 0.023387812077999115, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 44:, training loss = 0.0027295502368360758, validation_loss = 0.023392343893647194, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 45:, training loss = 0.002727694110944867, validation_loss = 0.023394301533699036, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 46:, training loss = 0.0027262489311397076, validation_loss = 0.02339511178433895, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 47:, training loss = 0.002724562305957079, validation_loss = 0.023398151621222496, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 48:, training loss = 0.002723321784287691, validation_loss = 0.02339927852153778, validation_accuracy = 0.992300, non_zero_p = 105506
# Epoch 49:, training loss = 0.0027216298040002584, validation_loss = 0.02339884825050831, validation_accuracy = 0.992300, non_zero_p = 105506
